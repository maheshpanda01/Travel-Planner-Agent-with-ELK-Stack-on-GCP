# %%
print("hello")
import os
# Out:
# hello

# %%
os.environ["GROQ_API_KEY"]=os.environ["GROQ_API_KEY"]
os.environ["TAVILY_API_KEY"]=os.environ["TAVILY_API_KEY"]
os.environ["SERPER_API_KEY"]=os.environ["SERPER_API_KEY"]

print("keys set")
# Out:
# keys set

# %%
from langchain_tavily import TavilySearch

# %%
tavily = TavilySearch(max_results=5, api_key=os.environ["TAVILY_API_KEY"],topic="general")
